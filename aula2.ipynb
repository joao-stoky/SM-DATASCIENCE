# %% [markdown]
# <a href="https://colab.research.google.com/github/joao-stoky/SM-DATASCIENCE/blob/main/aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/brazil_population.csv')
df.head(3)
# Out:
#    Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0  2020   212559417             0.72        1509890           21200
# 1  2019   211049527             0.75        1580204           21200
# 2  2018   209469323             0.79        1635500           21200
#
#    Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  Urban Population  \
# 0        33.5            1.74               25         87.6         186217070
# 1        31.8            1.76               25         87.4         184407548
# 2        31.8            1.76               25         87.1         182546459
#
#    Country's Share of World Pop  World Population  Brazil Global Rank
# 0                          2.73        7794798739                   6
# 1                          2.74        7713468100                   6
# 2                          2.74        7631091040                   6

# %%
df.tail(4)
# Out:
#     Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 14  1970    95113265             2.67        2347947               0
# 15  1965    83373530             2.93        2238861               0
# 16  1960    72179226             2.91        1929061               0
# 17  1955    62533919             2.99        1711838           59635
#
#     Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  \
# 14        18.6            5.34               11         56.0
# 15        18.3            5.97               10         51.1
# 16        18.6            6.06                9         46.2
# 17        18.9            6.10                7         41.1
#
#     Urban Population  Country's Share of World Pop  World Population  \
# 14          53295882                          2.57        3700437046
# 15          42615168                          2.50        3339583597
# 16          33315588                          2.38        3034949748
# ...

# %%
df.sample(7)
# Out:
#     Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 7   2005   186127103             1.26        2267353               0
# 13  1975   107216205             2.42        2420588               0
# 5   2015   204471769             0.88        1751627            3185
# 6   2010   195713635             1.01        1917306               0
# 14  1970    95113265             2.67        2347947               0
# 10  1990   149003223             1.95        2745829               0
# 8   2000   174790340             1.53        2554089               0
#
#     Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  \
# 7         27.1            2.13               22         83.2
# 13        19.5            4.63               13         61.0
# 5         31.4            1.77               24         86.4
# 6         29.2            1.86               23         84.8
# 14        18.6            5.34               11         56.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          18 non-null     int64
#  1   Population                    18 non-null     int64
#  2   Yearly % Change               18 non-null     float64
#  3   Yearly Change                 18 non-null     int64
#  4   Migrants (net)                18 non-null     int64
#  5   Median Age                    18 non-null     float64
#  6   Fertility Rate                18 non-null     float64
#  7   Density (P/Km²)               18 non-null     int64
#  8   Urban Pop %                   18 non-null     float64
#  9   Urban Population              18 non-null     int64
#  10  Country's Share of World Pop  18 non-null     float64
#  11  World Population              18 non-null     int64
# ...

# %%
df.describe()
# Out:
#               Year    Population  Yearly % Change  Yearly Change  \
# count    18.000000  1.800000e+01        18.000000   1.800000e+01
# mean   1994.166667  1.553103e+08         1.713889   2.121503e+06
# std      22.350813  5.333306e+07         0.862030   4.614891e+05
# min    1955.000000  6.253392e+07         0.720000   1.509890e+06
# 25%    1976.250000  1.105857e+08         0.842500   1.696422e+06
# 50%    1997.500000  1.684051e+08         1.610000   2.083961e+06
# 75%    2015.750000  2.057402e+08         2.415000   2.520714e+06
# max    2020.000000  2.125594e+08         2.990000   2.916014e+06
#
#        Migrants (net)  Median Age  Fertility Rate  Density (P/Km²)  \
# count       18.000000   18.000000       18.000000        18.000000
# mean      9378.888889   25.322222        3.278333        18.444444
# std      15774.762845    5.712376        1.687261         6.363704
# min          0.000000   18.300000        1.740000         7.000000
# ...
